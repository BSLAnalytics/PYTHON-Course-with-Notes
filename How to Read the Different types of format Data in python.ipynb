# %%
#HOW TO READ DATA IN PYTHON .EXCEL FILES,.CSV FILES,.JSON FILES
#IWHAT IS THE PURPOSE OF IMPORT COMMAND
#IMPORT COMMAND IS USED OF IMPORTING THE PACKAGES IN PYTHON FOR EXECUTING CODE
#SYTANX:IMPORT <PACKAGE NAME>
#IF U WANT ONE LIBRIES/MODULE FROM THAT PACKAGE
#SYANTAX:FROM <PACKAGE NAME> IMPORT <MWHAT MODULE U WANT>

#HEAD() .THIS FUNCTION IS USED FOR DISPLEY THE FIRST FEW ROWS IN YOUR DATA.
#TAIL().THIS FUNSTION IS USED FOR DISPLAY THE FROM LAST FEW ROWS IN YOUR DATA
#THIS TWO FUNSTION ONLY SHOWS 1ST 5ROWS
#IF U WANT FIRST 10 ROWS IN YOUR 
#HEAD(10)
#IY U WANT LAST 10 ROWS IN YOUR DATA 
#TAIL(10)

#SYNATX FOR HOW READ THE DATA
#<FILE NAME>=pd.read_<file format>(r'<paste the file path>')

#PANDAS PAKCGED IS MANDATORY
#HOW TO INSTALL PANDAS PACKAGE IN PYTHON

# %%
import pandas as pd

# %%
sales=pd.read_csv(r'C:\Users\user\Desktop\DATA_SETS\mobile_sales.csv')

# %%
sales.head()
# Out:
#                           TransactionID        Date MobileModel  \
# 0  79397f68-61ed-4ea8-bcb2-f918d4e6c05b  06-01-2024   direction
# 1  4f87d114-f522-4ead-93e3-f336402df6aa  05-04-2024       right
# 2  6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  13-02-2024      summer
# 3  7da7de95-f772-4cc2-bce0-b0873f98233e  17-04-2024        keep
# 4  469044af-0d60-4d87-af66-c6603e844057  02-06-2024      option
#
#               Brand    Price  UnitsSold  TotalRevenue  CustomerAge  \
# 0         Green Inc  1196.95         85      28002.80           32
# 1   Thomas-Thompson  1010.34         64       2378.82           55
# 2  Sanchez-Williams   400.80         95      31322.56           57
# 3    Greer and Sons   338.60         79      31159.75           46
# 4    Brown and Sons   839.79         41      11523.36           38
#
#   CustomerGender           Location PaymentMethod
# 0         Female          Port Erik        Online
# 1         Female         East Linda   Credit Card
# ...

# %%
sales.tail()
# Out:
#                             TransactionID        Date MobileModel  \
# 995  41f08915-addb-4966-8628-038c479c619a  28-01-2024   challenge
# 996  bcfa1912-5bd8-4894-900f-376fa48f022d  13-07-2024       least
# 997  e6839305-a177-4cda-aada-3ac1f49eeeec  13-01-2024       enjoy
# 998  12f7ac32-9063-4ae5-a122-385b06ba77af  25-01-2024        half
# 999  d3e82026-2084-40f2-8d5d-d2a94a198af9  17-01-2024        fill
#
#                           Brand    Price  UnitsSold  TotalRevenue  \
# 995                  Brooks Ltd  1386.69         76      28865.70
# 996       Lang, Brown and Stone  1159.26         59      50471.42
# 997  Atkinson, Moore and Nelson   544.31         59       1381.82
# 998      Kim, Maxwell and Moore   331.98         84       8557.32
# 999                 Wallace LLC   973.97         79      70739.76
#
#      CustomerAge CustomerGender           Location PaymentMethod
# 995           39           Male      Ronaldchester   Credit Card
# ...

# %%
sales.head(22)
# Out:
#                            TransactionID        Date MobileModel  \
# 0   79397f68-61ed-4ea8-bcb2-f918d4e6c05b  06-01-2024   direction
# 1   4f87d114-f522-4ead-93e3-f336402df6aa  05-04-2024       right
# 2   6750b7d6-dcc5-48c5-a76a-b6fc9d540fe1  13-02-2024      summer
# 3   7da7de95-f772-4cc2-bce0-b0873f98233e  17-04-2024        keep
# 4   469044af-0d60-4d87-af66-c6603e844057  02-06-2024      option
# 5   f7e98db9-cb87-453e-8179-e48ba5443932  07-03-2024        idea
# 6   61f1c03f-5527-49bf-88f6-0d8694e72d41  13-07-2024    southern
# 7   55d74ccb-e3c0-4ceb-a102-6d553736b944  18-03-2024         top
# 8   889bd479-e06a-494d-baae-e099bea5469c  12-04-2024    anything
# 9   567c276b-fec4-47e4-b5be-71f2b79bd745  19-04-2024        wall
# 10  f7d25e75-e7e6-4b61-8879-63121787a1dd  13-07-2024      happen
# 11  c28cafd9-08a6-4a72-8a89-b05d82993315  18-02-2024        very
# 12  1a9dfe22-c8d8-4872-8cb3-1e7d37c492a9  27-01-2024     nothing
# ...
